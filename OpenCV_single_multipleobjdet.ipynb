# %% [markdown]
# # 10 Step Framework for OpenCV Object Detection:

# %%
* Step 1: Import libraries
* Step 2: Import Model
* Step 3: Import Image/Video
* Step 4: Convert this into GreyScale
* Step 5: Use MultiscaleDetector to get the position co-ordinates
* Step 6: Use Looping statement to draw the Rectangular bounding box as much objects we get
* Step 7: Display the Image
* Step 8: Drop the Waitkey to Pause the Program for a given second, refresh it again and again, and get the Key to close
* Step 9: Kill the video/image frame
* Step 10: Close all the windows

# %% [markdown]
# # single object detection

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in C:\Users\varun\AppData\Local\Programs\Python\Python314\Lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in C:\Users\varun\AppData\Local\Programs\Python\Python314\Lib\site-packages (from opencv-python) (2.4.6)
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys

# !{sys.executable} -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in C:\Users\varun\anaconda3\envs\Tensor_flow\Lib\site-packages (from opencv-python) (2.5.1)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-5.0.0.93
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %% [markdown]
# ## Step 1: Import libraries

# %%
import cv2

# %% [markdown]
# ## Step 2: Import Model

# %%
# !{sys.executable} -m pip install opencv-python==4.10.0.84
# Out:
# Requirement already satisfied: opencv-python==4.10.0.84 in C:\Users\varun\anaconda3\envs\Tensor_flow\Lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in C:\Users\varun\anaconda3\envs\Tensor_flow\Lib\site-packages (from opencv-python==4.10.0.84) (2.5.1)

# %%
## go to raw github and search for opencv, under data all haarcascade prediction codes are present.

# %%
front_face_detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

# %% [markdown]
# ## step3 : Import image

# %%
image = cv2.imread("gates5.jpg")
cv2.imshow("image_window",image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ## Step 4: Convert this into GreyScale

# %%
grey_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow("image_window",grey_image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ## Step 5: Use MultiscaleDetector to get the position co-ordinates

# %%
face_detector = front_face_detector.detectMultiScale(grey_image)
print(face_detector)
# Out:
# [[70 44 83 83]]

# %% [markdown]
# ## Step 6: Use Looping statement to draw the Rectangular bounding box as much objects we get

# %%
for x,y,w,h in face_detector:
    cv2.rectangle(grey_image,(x,y),(x+w,y+h),(0,0,0))
# Out:
# -1

# %% [markdown]
# ## Step 7: Display the Image

# %% [markdown]
# ## Step 8: Drop the Waitkey to Pause the Program for a given second, refresh it again and again, and get the Key to close

# %%
cv2.imshow("image_window",grey_image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ## Step 9: Kill the video/image frame - Not applicable for images

# %% [markdown]
# ## Step 10: Close all the windows

# %%
cv2.destroyAllWindows()

# %% [markdown]
# # Multiple object detection

# %%
import cv2

front_face_detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
image = cv2.imread("multiface.jpg")
grey_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
face_detector = front_face_detector.detectMultiScale(grey_image)
print(face_detector)

for x,y,w,h in face_detector:
    cv2.rectangle(grey_image,(x,y),(x+w,y+h),(0,0,0),3)
cv2.imshow("image_window",grey_image)
cv2.waitKey()
# Out:
# [[ 74  64  45  45]
#  [ 20  55  43  43]
#  [162  47  47  47]
#  [243  43  52  52]]
# -1
